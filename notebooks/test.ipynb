# %% [markdown]
# # Example Jupyter Notebook
# This notebook demonstrates a few basic cells: a Markdown cell, a simple Python code cell, and a small data visualization.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Simple Calculation
# Below is an example of a short Python script that performs a basic calculation, just to confirm everything is working.

# %%
x = 5
y = 3
result = x ** y
print("Result of", x, "raised to the power of", y, "is", result)
# Out:
# Result of 5 raised to the power of 3 is 125

# %% [markdown]
# ## Simple Data Visualization
# This example uses Matplotlib to plot a basic chart.

# %%
import matplotlib.pyplot as plt

data = [1, 4, 2, 8, 3, 7]
plt.plot(data, marker='o')
plt.title('Simple Plot')
plt.xlabel('X-axis')
plt.ylabel('Values')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
